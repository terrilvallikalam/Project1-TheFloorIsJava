# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import the netflix_titles.csv file as a DataFrame
netflix_df = pd.read_csv("Resources/clean_netflix.csv", encoding="utf-8")
netflix_df.head()
# Out:
#   Movie/TV Show  Title           Director  \
# 0       TV Show     3%                NaN
# 1         Movie   7:19  Jorge Michel Grau
# 2         Movie  23:59       Gilbert Chan
# 3         Movie      9        Shane Acker
# 4         Movie     21     Robert Luketic
#
#                                                 Cast Date Added to Netflix  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...       August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     December 23, 2016
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...     December 20, 2018
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...     November 16, 2017
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...       January 1, 2020
#
#    Release Year Parental Rating   Duration  \
# 0          2020           TV-MA  4 Seasons
# 1          2016           TV-MA     93 min
# 2          2011               R     78 min
# 3          2009           PG-13     80 min
# 4          2008           PG-13    123 min
#
#                                                Genre  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#   Calendar Date Added to Netflix  ...  Country 3 Country 4 Country 5  \
# 0                      August 14  ...        NaN       NaN       NaN
# 1                    December 23  ...        NaN       NaN       NaN
# 2                    December 20  ...        NaN       NaN       NaN
# 3                    November 16  ...        NaN       NaN       NaN
# 4                      January 1  ...        NaN       NaN       NaN
#
#   Country 6 Country 7 Country 8 Country 9 Country 10 Country 11 Country 12
# 0       NaN       NaN       NaN       NaN        NaN        NaN        NaN
# 1       NaN       NaN       NaN       NaN        NaN        NaN        NaN
# 2       NaN       NaN       NaN       NaN        NaN        NaN        NaN
# 3       NaN       NaN       NaN       NaN        NaN        NaN        NaN
# 4       NaN       NaN       NaN       NaN        NaN        NaN        NaN
#
# [5 rows x 23 columns]

# %%
duration_split = netflix_df["Duration"].str.split(' ', expand=True).rename(columns={0:"Run Length"})
netflix = netflix_df.join([duration_split])
netflix.head()
# Out:
#   Movie/TV Show  Title           Director  \
# 0       TV Show     3%                NaN
# 1         Movie   7:19  Jorge Michel Grau
# 2         Movie  23:59       Gilbert Chan
# 3         Movie      9        Shane Acker
# 4         Movie     21     Robert Luketic
#
#                                                 Cast Date Added to Netflix  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...       August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     December 23, 2016
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...     December 20, 2018
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...     November 16, 2017
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...       January 1, 2020
#
#    Release Year Parental Rating   Duration  \
# 0          2020           TV-MA  4 Seasons
# 1          2016           TV-MA     93 min
# 2          2011               R     78 min
# 3          2009           PG-13     80 min
# 4          2008           PG-13    123 min
#
#                                                Genre  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#   Calendar Date Added to Netflix  ...  Country 5 Country 6 Country 7  \
# 0                      August 14  ...        NaN       NaN       NaN
# 1                    December 23  ...        NaN       NaN       NaN
# 2                    December 20  ...        NaN       NaN       NaN
# 3                    November 16  ...        NaN       NaN       NaN
# 4                      January 1  ...        NaN       NaN       NaN
#
#   Country 8 Country 9 Country 10 Country 11 Country 12 Run Length        1
# 0       NaN       NaN        NaN        NaN        NaN          4  Seasons
# 1       NaN       NaN        NaN        NaN        NaN         93      min
# 2       NaN       NaN        NaN        NaN        NaN         78      min
# 3       NaN       NaN        NaN        NaN        NaN         80      min
# 4       NaN       NaN        NaN        NaN        NaN        123      min
#
# [5 rows x 25 columns]

# %%
netflix.dtypes
# Out:
# Movie/TV Show                      object
# Title                              object
# Director                           object
# Cast                               object
# Date Added to Netflix              object
# Release Year                        int64
# Parental Rating                    object
# Duration                           object
# Genre                              object
# Calendar Date Added to Netflix     object
# Year Added to Netflix             float64
# Country 1                          object
# Country 2                          object
# Country 3                          object
# Country 4                          object
# Country 5                          object
# Country 6                          object
# Country 7                          object
# Country 8                          object
# Country 9                          object
# Country 10                         object
# Country 11                         object
# Country 12                         object
# Run Length                         object
# 1                                  object
# dtype: object

# %%
netflix["Run Length"] = pd.to_numeric(netflix["Run Length"])
# netflix["Year Added to Netflix"] = netflix["Year Added to Netflix"].astype(int)
netflix.dtypes
# Out:
# Movie/TV Show                      object
# Title                              object
# Director                           object
# Cast                               object
# Date Added to Netflix              object
# Release Year                        int64
# Parental Rating                    object
# Duration                           object
# Genre                              object
# Calendar Date Added to Netflix     object
# Year Added to Netflix             float64
# Country 1                          object
# Country 2                          object
# Country 3                          object
# Country 4                          object
# Country 5                          object
# Country 6                          object
# Country 7                          object
# Country 8                          object
# Country 9                          object
# Country 10                         object
# Country 11                         object
# Country 12                         object
# Run Length                          int64
# 1                                  object
# dtype: object

# %%
netflix = netflix.set_index("Title")
netflix.head()
# Out:
#       Movie/TV Show           Director  \
# Title
# 3%          TV Show                NaN
# 7:19          Movie  Jorge Michel Grau
# 23:59         Movie       Gilbert Chan
# 9             Movie        Shane Acker
# 21            Movie     Robert Luketic
#
#                                                     Cast  \
# Title
# 3%     João Miguel, Bianca Comparato, Michel Gomes, R...
# 7:19   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 9      Elijah Wood, John C. Reilly, Jennifer Connelly...
# 21     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#
#       Date Added to Netflix  Release Year Parental Rating   Duration  \
# Title
# 3%          August 14, 2020          2020           TV-MA  4 Seasons
# 7:19      December 23, 2016          2016           TV-MA     93 min
# 23:59     December 20, 2018          2011               R     78 min
# 9         November 16, 2017          2009           PG-13     80 min
# 21          January 1, 2020          2008           PG-13    123 min
#
#                                                    Genre  \
# Title
# 3%     International TV Shows, TV Dramas, TV Sci-Fi &...
# 7:19                        Dramas, International Movies
# 23:59                Horror Movies, International Movies
# 9      Action & Adventure, Independent Movies, Sci-Fi...
# 21                                                Dramas
#
#       Calendar Date Added to Netflix  Year Added to Netflix  ... Country 5  \
# Title                                                        ...
# 3%                         August 14                 2020.0  ...       NaN
# 7:19                     December 23                 2016.0  ...       NaN
# 23:59                    December 20                 2018.0  ...       NaN
# 9                        November 16                 2017.0  ...       NaN
# 21                         January 1                 2020.0  ...       NaN
#
#       Country 6 Country 7 Country 8 Country 9 Country 10 Country 11  \
# Title
# 3%          NaN       NaN       NaN       NaN        NaN        NaN
# 7:19        NaN       NaN       NaN       NaN        NaN        NaN
# 23:59       NaN       NaN       NaN       NaN        NaN        NaN
# 9           NaN       NaN       NaN       NaN        NaN        NaN
# 21          NaN       NaN       NaN       NaN        NaN        NaN
#
#       Country 12 Run Length        1
# Title
# 3%           NaN          4  Seasons
# 7:19         NaN         93      min
# 23:59        NaN         78      min
# 9            NaN         80      min
# 21           NaN        123      min
#
# [5 rows x 24 columns]

# %%
# netflix_remove = netflix.loc[netflix["Year Added to Netflix"] == 'N/A']
# netflix_remove

#To be able to change the Year Added to int, we need to delete the one from the original data set that don't
#have a date added becasue it won't let you change a data series if all of the data types aren't the same

# %%
# Number of Movies vs. TV Shows
netflix['Movie/TV Show'].value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: Movie/TV Show, dtype: int64

# %%
labels = ["Movies", "TV Shows"]
sizes = [5377, 2410]
colors = ["lightcoral", "cyan"]
plt.pie(sizes, labels=labels, colors=colors, autopct="%1.1f%%", startangle=0, explode=[0, 0.05], shadow=True)
plt.title("Percentage of Movies and TV Shows on Netflix")
plt.show()

# %%
netflix.groupby(["Year Added to Netflix", "Movie/TV Show"]).size().unstack().plot(kind='bar', stacked=True,
                                                                                    legend="upper left", figsize=(8,8))
plt.title("Number of Movies and TV Shows Added to Netflix Each Year")                                                                
plt.show()

# %%
# Length of movies vs. release date - scatterplot
movie_duration = netflix.loc[netflix["Movie/TV Show"] == "Movie"]
movie_duration.plot(kind="scatter", x="Year Added to Netflix", y="Run Length", figsize=(8,8),
                   title="Movie Run Time vs. Year Added to Netflix")
plt.show()

# %%
# Length of shows vs. release date - scatterplot
tvshow_duration = netflix.loc[netflix["Movie/TV Show"] == "TV Show"]
tvshow_duration.plot(kind="scatter", x="Year Added to Netflix", y="Run Length", figsize=(8,8),
                   title="Number of Seasons vs. Year Added to Netflix")
plt.show()

# %%
# Release date vs. Year Added to Netflix - scatterplot
netflix.plot(kind="scatter", x="Year Added to Netflix", y="Release Year", figsize=(8,8),
                   title="Number of Seasons vs. Year Added to Netflix")
plt.show()

# %%
netflix.groupby(["Year Added to Netflix", "Parental Rating"]).size().unstack().plot(kind='bar', stacked=True,
                                                                                    legend="upper left", figsize=(8,8))
                                                                
plt.show()
# need to figure out how to remove the y axis labels since we arent' measureing anything
